# %%
import pandas as pd 
df = pd.read_csv("/workspace/adresses-59.csv", sep = ";")
df.columns
df = df[['id', 'numero', 'rep',  'code_postal',
       'code_insee', 'nom_commune', 
        'lon', 'lat', 
         'nom_afnor',]]
df_grouped_table1 = df.groupby([ 
        'code_postal',
        'nom_commune', 
         'nom_afnor',]).agg(['unique'])
df_grouped_table1 = df_grouped_table1.reset_index()
df.head(10)
df_grouped_table1 = df_grouped_table1[[ 
        'code_postal',
        'nom_commune', 
         'nom_afnor',]]
df_grouped_table2 = df.groupby([ 
        'code_postal', 
         'nom_commune',]).agg(['unique'])
df_grouped_table2 = df_grouped_table2.reset_index()
df_grouped_table2 = df_grouped_table2[[ 
        'code_postal',
          'nom_commune',]]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("/workspace/adresses-59.csv", sep = ";")
#       3 df.columns
#       4 df = df[['id', 'numero', 'rep',  'code_postal',
#       5        'code_insee', 'nom_commune',
#       6         'lon', 'lat',
#       7          'nom_afnor',]]
#
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://admin:LocalPasswordOnly@localhost:5432/postgres')
"""df.to_sql('table_name', engine)"""
# Out:
# /tmp/ipykernel_28373/2825433233.py:1: DtypeWarning: Columns (9,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/workspace/adresses-59.csv", sep = ";")

# %%
"""engine = create_engine('postgresql://admin:LocalPasswordOnly@localhost:5432/postgres')
df_grouped_table1.to_sql('cp_ville_rue', engine)"""
"""engine = create_engine('postgresql://admin:LocalPasswordOnly@localhost:5432/postgres')
df_grouped_table2.to_sql('cp_ville', engine)"""
# Out:
#                    id  id_fantoir  numero  rep            nom_voie  \
# 0  59001_nhsgdi_00001         NaN       1  NaN  Chemin Hem Lenglet
# 1    59001_0270_00001  59001_0270       1  NaN   Rue Yves Défossez
# 2    59001_0270_00002  59001_0270       2  NaN   Rue Yves Défossez
# 3    59001_0270_00003  59001_0270       3  NaN   Rue Yves Défossez
# 4    59001_0270_00004  59001_0270       4  NaN   Rue Yves Défossez
# 5    59001_0270_00005  59001_0270       5  NaN   Rue Yves Défossez
# 6    59001_0270_00006  59001_0270       6  NaN   Rue Yves Défossez
# 7    59001_0270_00007  59001_0270       7  NaN   Rue Yves Défossez
# 8    59001_0270_00008  59001_0270       8  NaN   Rue Yves Défossez
# 9    59001_0270_00009  59001_0270       9  NaN   Rue Yves Défossez
#
#    code_postal  code_insee nom_commune  code_insee_ancienne_commune  \
# 0        59268       59001   Abancourt                          NaN
# 1        59268       59001   Abancourt                          NaN
# ...

# %%
# Out:
# Index(['id', 'id_fantoir', 'numero', 'rep', 'nom_voie', 'code_postal',
#        'code_insee', 'nom_commune', 'code_insee_ancienne_commune',
#        'nom_ancienne_commune', 'x', 'y', 'lon', 'lat', 'type_position',
#        'alias', 'nom_ld', 'libelle_acheminement', 'nom_afnor',
#        'source_position', 'source_nom_voie', 'certification_commune',
#        'cad_parcelles'],
#       dtype='object')

# %%
# Out:
#                    id  numero  rep  code_postal  code_insee nom_commune  \
# 0  59001_nhsgdi_00001       1  NaN        59268       59001   Abancourt
# 1    59001_0270_00001       1  NaN        59268       59001   Abancourt
# 2    59001_0270_00002       2  NaN        59268       59001   Abancourt
# 3    59001_0270_00003       3  NaN        59268       59001   Abancourt
# 4    59001_0270_00004       4  NaN        59268       59001   Abancourt
# 5    59001_0270_00005       5  NaN        59268       59001   Abancourt
# 6    59001_0270_00006       6  NaN        59268       59001   Abancourt
# 7    59001_0270_00007       7  NaN        59268       59001   Abancourt
# 8    59001_0270_00008       8  NaN        59268       59001   Abancourt
# 9    59001_0270_00009       9  NaN        59268       59001   Abancourt
#
#         lon        lat           nom_afnor
# 0  3.218633  50.234189  CHEMIN HEM LENGLET
# 1  3.213229  50.234075   RUE YVES DEFOSSEZ
# 2  3.213088  50.234025   RUE YVES DEFOSSEZ
# ...

# %%
df_grouped_table1
# Out:
#       code_postal nom_commune                      nom_afnor
#
# 0           59000       Lille  ALL M THERESE VICOT LHERMITTE
# 1           59000       Lille             ALLEE ANDRE CARTON
# 2           59000       Lille                  ALLEE CAROLUS
# 3           59000       Lille               ALLEE CHANTELOUP
# 4           59000       Lille         ALLEE CLEMENTINE DEMAN
# ...           ...         ...                            ...
# 42867       59990     Sebourg                       RUE LABY
# 42868       59990     Sebourg                   RUE LANDELIN
# 42869       59990     Sebourg      RUE PHILIBERT DASSONVILLE
# 42870       59990     Sebourg    RUE VERIMETZ RES ST EXUPERY
# 42871       59990     Sebourg                       WARGNIES
#
# [42872 rows x 3 columns]

# %%
df_grouped_table2
# Out:
#     code_postal            nom_commune
#
# 0         59000                  Lille
# 1         59000                Ronchin
# 2         59100                Roubaix
# 3         59110           La Madeleine
# 4         59111               Bouchain
# ..          ...                    ...
# 659       59990              Maresches
# 660       59990                Préseau
# 661       59990  Rombies-et-Marchipont
# 662       59990               Saultain
# 663       59990                Sebourg
#
# [664 rows x 2 columns]

# %%
# Out:
# "df.to_sql('table_name', engine)"

# %%
# Out:
# "engine = create_engine('postgresql://admin:LocalPasswordOnly@localhost:5432/postgres')\ndf_grouped_table1.to_sql('cp_ville_rue', engine)"

# %%
# Out:
# "engine = create_engine('postgresql://admin:LocalPasswordOnly@localhost:5432/postgres')\ndf_grouped_table2.to_sql('cp_ville', engine)"

# %%
sql = "select * from table2"

# %%
df = pd.read_sql(sql,con=engine)

# %%
df
# Out:
#       index  ('code_postal', '') ('nom_commune', '')  \
# 0      None                59000               Lille
# 1      None                59000               Lille
# 2      None                59000               Lille
# 3      None                59000               Lille
# 4      None                59000               Lille
# ...     ...                  ...                 ...
# 42867  None                59990             Sebourg
# 42868  None                59990             Sebourg
# 42869  None                59990             Sebourg
# 42870  None                59990             Sebourg
# 42871  None                59990             Sebourg
#
#                    ('nom_afnor', '')
# 0      ALL M THERESE VICOT LHERMITTE
# 1                 ALLEE ANDRE CARTON
# 2                      ALLEE CAROLUS
# 3                   ALLEE CHANTELOUP
# 4             ALLEE CLEMENTINE DEMAN
# ...                              ...
# 42867                       RUE LABY
# ...

# %%
with engine.connect() as connection:
    cursor = connection

# %%
cursor
